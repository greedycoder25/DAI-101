# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 308          309         0       2                    Abelson, Mr. Samuel
# 755          756         1       2              Hamalainen, Master. Viljo
# 95            96         0       3            Shorney, Mr. Charles Joseph
# 21            22         1       2                  Beesley, Mr. Lawrence
# 304          305         0       3      Williams, Mr. Howard Hugh "Harry"
# 59            60         0       3     Goodwin, Master. William Frederick
# 326          327         0       3              Nysveen, Mr. Johan Hansen
# 822          823         0       1        Reuchlin, Jonkheer. John George
# 774          775         1       2  Hocking, Mrs. Elizabeth (Eliza Needs)
# 649          650         1       3        Stanley, Miss. Amy Zillah Elsie
#
#         Sex    Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 308    male  30.00      1      0  P/PP 3381  24.0000   NaN        C
# 755    male   0.67      1      1     250649  14.5000   NaN        S
# 95     male    NaN      0      0     374910   8.0500   NaN        S
# 21     male  34.00      0      0     248698  13.0000   D56        S
# 304    male    NaN      0      0   A/5 2466   8.0500   NaN        S
# 59     male  11.00      5      2    CA 2144  46.9000   NaN        S
# 326    male  61.00      0      0     345364   6.2375   NaN        S
# 822    male  38.00      0      0      19972   0.0000   NaN        S
# 774  female  54.00      1      3      29105  23.0000   NaN        S
# 649  female  23.00      0      0   CA. 2314   7.5500   NaN        S

# %%
df.select_dtypes(include=[np.number]).corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# Scatter Plot

# %%
sns.scatterplot(x=df["Age"], y=df["Fare"], alpha=0.6, edgecolor=None)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
#Box Plot

# %%
sns.boxplot(x=df['Sex'],y=df['Age'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#Violin Plot

# %%
sns.violinplot(x=df['Sex'],y=df['Age'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
